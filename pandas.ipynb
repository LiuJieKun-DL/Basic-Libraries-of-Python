# %%
import pandas as pd
#df = pd.read_csv('/Users/liujiekun/Desktop/案例分析/pokemon_data.csv')
# df_xlsx = pd.read_excel('/Users/liujiekun/Downloads/pokemon_data.xlsx')
# print(df_xlsx)
#print(df.tail(3))
df = pd.read_csv('/Users/liujiekun/Desktop/案例分析/pokemon_data.txt',delimiter='\t')
print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
import pandas as pd
#df = pd.read_csv('/Users/liujiekun/Desktop/案例分析/pokemon_data.csv')
# df_xlsx = pd.read_excel('/Users/liujiekun/Downloads/pokemon_data.xlsx')
# print(df_xlsx)
#print(df.tail(3))
df = pd.read_csv('/Users/liujiekun/Desktop/案例分析/pokemon_data.txt',delimiter='\t')
print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
## Read Headers
#df.columns
## Read each Column
#df[['Name','Type 1','HP']]

# %%
## Read each Row 
# df.iloc[2,1]
for index,row in df.iterrows():
     print(index,row['Name'])
#df.loc[df['Type 1']=='Grass']
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %% [markdown]
# ## Sorting/Describing Data

# %%
df.sort_values(['Type 1','HP'],ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## Making changes to the data

# %%
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
# df = df.drop(columns=['Total'])
df['Total'] = df.iloc[:,4:10].sum(axis=1)

# cols = list(df.columns)
# df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %% [markdown]
# ## Saving our data

# %%
#df.to_csv('modified.csv',index=False)
#df.to_csv('modified.txt',index=False,sep='\t')

# %% [markdown]
# ## Filtering Data

# %%
# new_df = df.loc[(df['Type 1']=='Grass')&(df['Type 2']=='Poison')&(df['HP']>70)]

# %%
# new_df.reset_index(drop=True,inplace=True)

# %%
import re
#df.loc[~df['Name'].str.contains('Mega')]#add ~ in the front then filter all the key words
#df.loc[df['Type 1'].str.contains('fire|grass',flags=re.I,regex=True)]
df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I,regex=True)]# * meant ZERO or MORE ; ^ make sure that pi are listed initially
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %% [markdown]
# ## Conditional Changes

# %%
# df.loc[df['Type 1'] == 'Fire','Legendary'] = True

# %%
df = pd.read_csv('modified.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary   Total  HP  \
# 0      1              Bulbasaur    Grass  Poison      False  1215.0  45
# 1      2                Ivysaur    Grass  Poison      False  1545.0  60
# 2      3               Venusaur    Grass  Poison      False  2005.0  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  2445.0  80
# 4      4             Charmander     Fire     NaN      False  1135.0  39
# ..   ...                    ...      ...     ...        ...     ...  ..
# 795  719                Diancie     Rock   Fairy       True  2353.0  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True  2733.0  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  2333.0  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  2693.0  80
# 799  721              Volcanion     Fire   Water       True  2453.0  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
# df.loc[df['Total'] > 500,['Generation','Legendary']] = ['Test 1','Test 2']

# %% [markdown]
# ## Aggregate Statistics(Group By)

# %%
df = pd.read_csv('modified.csv')
#df.groupby(['Type 1']).mean().sort_values('HP',ascending=False)
df['Count'] = 1
df.groupby(['Type 1','Type 2']).count()['Count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Count, Length: 136, dtype: int64

# %% [markdown]
# ## Working with large amounts of data

# %%
new_df = pd.DataFrame(columns=df.columns)
for df in pd.read_csv('modified.csv',chunksize=5):
    results = df.groupby(['Type 1']).count()
    
    new_df = pd.concat([new_df,results],ignore_index=True)

# %%
new_df
# Out:
#      # Name Type 1 Type 2 Legendary Total HP Attack Defense Sp. Atk Sp. Def  \
# 0    1    1    NaN      0         1     1  1      1       1       1       1
# 1    4    4    NaN      4         4     4  4      4       4       4       4
# 2    4    4    NaN      3         4     4  4      4       4       4       4
# 3    1    1    NaN      0         1     1  1      1       1       1       1
# 4    2    2    NaN      0         2     2  2      2       2       2       2
# ..  ..  ...    ...    ...       ...   ... ..    ...     ...     ...     ...
# 428  1    1    NaN      0         1     1  1      1       1       1       1
# 429  2    2    NaN      2         2     2  2      2       2       2       2
# 430  1    1    NaN      1         1     1  1      1       1       1       1
# 431  2    2    NaN      2         2     2  2      2       2       2       2
# 432  2    2    NaN      2         2     2  2      2       2       2       2
#
#     Speed Generation Count
# 0       1          1   NaN
# ...
